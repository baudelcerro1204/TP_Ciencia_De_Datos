# %%
# TP_Ciencia_de_Datos/notebooks/MillionSongDataset_AED.ipynb

# Celda 1: Imports y setup
import sys
from pathlib import Path
sys.path.append(str(Path('../src/songrecommender').resolve()))

import pandas as pd
from processors.data_processing import MillionSongDataProcessor  # Asegúrate que la clase esté en este archivo

# %%
# Celda 2: Procesar datos
processor = MillionSongDataProcessor()
df = processor.process_all()

print(f"Dataset combinado con {len(df)} filas y {len(df.columns)} columnas")
# Out:
# 🔍 Cargando Music Info desde ..\data\raw\Music Info.csv
#    → 50683 filas, columnas: ['track_id', 'name', 'artist', 'spotify_preview_url', 'spotify_id', 'tags', 'genre', 'year', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']
# 🧹 Music Info limpio: 50683 filas
# 🔍 Cargando User Listening History desde ..\data\raw\User Listening History.csv
#    → 9711301 filas, columnas: ['track_id', 'user_id', 'playcount']
# 🔄 Combinando datasets por track_id
#    → Data combinada tiene 9711301 filas y columnas ['track_id', 'user_id', 'playcount', 'name', 'artist', 'spotify_preview_url', 'spotify_id', 'tags', 'genre', 'year', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']
# 🗑 Eliminando columnas no útiles para comparación: ['valence', 'tempo', 'playcount', 'year', 'mode', 'key', 'time_signature']
# 💾 Dataset combinado guardado en: ..\data\processed\million_song_combined.parquet
# Dataset combinado con 9711301 filas y 16 columnas

# %%
# Celda 3: Vista previa de datos
print(df.columns.tolist())
df.head(15)
# Out:
# ['track_id', 'user_id', 'name', 'artist', 'spotify_preview_url', 'spotify_id', 'tags', 'genre', 'duration_ms', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness']
#               track_id                                   user_id  \
# 0   TRIRLYL128F42539D1  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1   TRFUPBA128F934F7E1  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2   TRLQPQJ128F42AA94F  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3   TRTUCUY128F92E1D24  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4   TRHDDQG12903CB53EE  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5   TRGRDEC128F423C07D  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6   TRRYCBO128F932A2C7  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 7   TRUTULC128F4293712  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8   TRAAHSY128F147BB5C  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9   TRDLMWP128F426BF6C  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 10  TRMSZXT128F92F7816  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 11  TRVODUZ128F934D094  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 12  TRLXSNR128F429361D  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 13  TRPUGUW128F426BF6F  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 14  TRAUCNU128F42671EB  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                              name                artist  \
# 0            nothing from nothing         billy preston
# 1                   paper gangsta             lady gaga
# 2                             soy           gipsy kings
# 3                  stacked actors          foo fighters
# 4   heaven's gonna burn your eyes  thievery corporation
# 5                  let it be sung          jack johnson
# 6                      love shack            the b-52's
# 7                  gimme stitches          foo fighters
# 8                  speed of sound              coldplay
# 9                     ragged wood           fleet foxes
# 10           love song for no one            john mayer
# 11           all that we perceive  thievery corporation
# 12                      generator          foo fighters
# 13            he doesn't know why           fleet foxes
# 14              tu quieres volver       sarah brightman
#
#                                   spotify_preview_url              spotify_id  \
# 0   https://p.scdn.co/mp3-preview/340c79f3f19b448e...  0d42LKqrWFVu05jAv9mwwE
# 1   https://p.scdn.co/mp3-preview/5d27f0eb10363c13...  079ZOccLpNsrEiKBaiTrqI
# 2   https://p.scdn.co/mp3-preview/a103c32c238829f9...  1D3gFdVhv8iJNMTih2Geq3
# 3   https://p.scdn.co/mp3-preview/d7350c743c3d917f...  1vziI0NCJKrqKiG94COHBa
# 4   https://p.scdn.co/mp3-preview/c7f3b22fb4a680f0...  4SnH0V1cnEPUqMSzgDlxKb
# 5   https://p.scdn.co/mp3-preview/4615607c424de3c1...  3YPpiU7RGEsokqwrK3unSJ
# 6   https://p.scdn.co/mp3-preview/33813193c01f1c42...  05r7cs15qOMZFRTMxszL8P
# 7   https://p.scdn.co/mp3-preview/3652c6d3c9317729...  1MEbfjEGUiOtdOUjNpnbdm
# 8   https://p.scdn.co/mp3-preview/739f1ff67c5b9a41...  1CAPtD2FgB23xGewa3nqkg
# 9   https://p.scdn.co/mp3-preview/621d6510eb943d85...  0CCnBol2JNuwYxdMvhamcA
# 10  https://p.scdn.co/mp3-preview/5819e2adac5fbaae...  2L4no3iw54gGX1ZwCNfYSL
# 11  https://p.scdn.co/mp3-preview/6d67b3fb926f368a...  2WgES78IqFOgfGoTiQjoNr
# 12  https://p.scdn.co/mp3-preview/c61e0d64aed48a13...  592nTDJAy8AucV4KKIDCmA
# 13  https://p.scdn.co/mp3-preview/a8591fb5edfa475b...  10lOVrdkSTb9zkmb5D7aR8
# 14  https://p.scdn.co/mp3-preview/52961aa62fa41dc5...  675FOf7peFJTgQgiJ3OKsD
#
#                                                  tags       genre  \
# 0                      soul, funk, piano, 70s, oldies         rnb
# 1   electronic, pop, female_vocalists, dance, pian...         pop
# 2                                              guitar
# 3   rock, alternative, alternative_rock, hard_rock...        rock
# 4   electronic, female_vocalists, ambient, chillou...  electronic
# 5      singer_songwriter, soundtrack, acoustic, chill
# 6        rock, alternative, pop, dance, 80s, new_wave
# 7           rock, alternative_rock, hard_rock, grunge        rock
# 8   rock, alternative, indie, pop, alternative_roc...        rock
# 9   rock, alternative, indie, folk, indie_rock, 00...
# 10  rock, pop, singer_songwriter, acoustic, male_v...        rock
# 11  electronic, ambient, chillout, trip_hop, downt...  electronic
# 12  rock, alternative, alternative_rock, hard_rock...        rock
# 13  rock, alternative, indie, folk, indie_rock, am...        rock
# 14               female_vocalists, classical, new_age
#
#     duration_ms  danceability  energy  loudness  speechiness  acousticness  \
# 0        155453         0.759   0.834    -5.206       0.0276       0.58500
# 1        260000         0.823   0.530    -9.344       0.0579       0.80400
# 2        187106         0.797   0.592   -11.647       0.0673       0.69200
# 3        256440         0.502   0.934    -5.145       0.0500       0.00203
# 4        250360         0.516   0.337    -9.812       0.0286       0.63500
# 5        248346         0.565   0.469   -10.735       0.0303       0.27700
# 6        323586         0.662   0.902    -4.407       0.0532       0.04110
# 7        222200         0.538   0.958    -4.423       0.0680       0.00212
# 8        287906         0.523   0.898    -6.765       0.0567       0.00491
# 9        305320         0.355   0.685    -5.963       0.0299       0.10300
# 10       201560         0.528   0.755    -4.671       0.0311       0.03520
# 11       226159         0.697   0.834    -6.470       0.0336       0.02630
# 12       227560         0.468   0.924    -3.937       0.0410       0.00112
# 13       199560         0.496   0.558    -5.535       0.0302       0.21300
# 14       229040         0.446   0.376    -9.766       0.0278       0.83600
#
#     instrumentalness  liveness
# 0           0.055000    0.3310
# 1           0.782000    0.1050
# 2           0.000002    0.1100
# 3           0.001020    0.2340
# 4           0.521000    0.0637
# 5           0.000744    0.3010
# 6           0.000000    0.7180
# 7           0.002150    0.2410
# 8           0.034500    0.0746
# 9           0.011400    0.0624
# 10          0.000000    0.3450
# 11          0.937000    0.0801
# 12          0.014900    0.3370
# 13          0.000302    0.3440
# 14          0.116000    0.1210

# %%
# Celda 4: Estadísticas básicas
print("Estadísticas numéricas:")
display(df.describe())
# Out:
# Estadísticas numéricas:
#         duration_ms  danceability        energy      loudness   speechiness  \
# count  9.711301e+06  9.711301e+06  9.711301e+06  9.711301e+06  9.711301e+06
# mean   2.458999e+05  5.286417e-01  6.781073e-01 -7.825038e+00  7.136620e-02
# std    9.017579e+04  1.708274e-01  2.362942e-01  3.952011e+00  7.312056e-02
# min    1.439000e+03  0.000000e+00  0.000000e+00 -6.000000e+01  0.000000e+00
# 25%    1.979460e+05  4.130000e-01  5.230000e-01 -9.623000e+00  3.350000e-02
# 50%    2.335730e+05  5.320000e-01  7.250000e-01 -6.919000e+00  4.440000e-02
# 75%    2.750400e+05  6.480000e-01  8.810000e-01 -5.089000e+00  7.450000e-02
# max    2.510920e+06  9.860000e-01  1.000000e+00  3.642000e+00  9.540000e-01
#
#        acousticness  instrumentalness      liveness
# count  9.711301e+06      9.711301e+06  9.711301e+06
# mean   2.206536e-01      1.679303e-01  2.047823e-01
# std    2.971524e-01      2.992913e-01  1.686200e-01
# min    0.000000e+00      0.000000e+00  0.000000e+00
# 25%    4.230000e-03      3.830000e-06  9.750000e-02
# 50%    6.110000e-02      1.140000e-03  1.330000e-01
# 75%    3.430000e-01      1.540000e-01  2.760000e-01
# max    9.960000e-01      9.990000e-01  9.980000e-01

# %%
# Celda 5: Conteo de géneros (puede tener nulos)
print("Top 10 géneros más frecuentes:")
genre_counts = df['genre'].fillna('unknown').value_counts().head(10)
display(genre_counts)
# Out:
# Top 10 géneros más frecuentes:
# genre
# rock          3421185
#               3388151
# electronic     863233
# pop            519802
# rap            329210
# metal          327676
# country        219870
# folk           164813
# rnb            131583
# reggae          81630
# Name: count, dtype: int64

# %%
# Celda 7: Top 10 artistas por número de escuchas
top_artists = df.groupby('artist').sum().sort_values(ascending=False).head(20)
print("Top 20 artistas por playcount:")
display(top_artists)
