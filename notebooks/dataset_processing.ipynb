# %%
# TP_Ciencia_de_Datos/notebooks/MillionSongDataset_AED.ipynb

# Celda 1: Imports y setup
import sys
from pathlib import Path
sys.path.append(str(Path('../src/songrecommender').resolve()))

import pandas as pd
from processors.data_processing import MillionSongDataProcessor  # Asegúrate que la clase esté en este archivo

# %%
# Celda 2: Procesar datos
processor = MillionSongDataProcessor()
df = processor.process_all()

print(f"Dataset combinado con {len(df)} filas y {len(df.columns)} columnas")
# Out:
# 🔍 Cargando Music Info desde ..\data\raw\Music Info.csv
#    → 50683 filas, columnas: ['track_id', 'name', 'artist', 'spotify_preview_url', 'spotify_id', 'tags', 'genre', 'year', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']
# 🧹 Music Info limpio: 50683 filas
# 🔍 Cargando User Listening History desde ..\data\raw\User Listening History.csv
#    → 9711301 filas, columnas: ['track_id', 'user_id', 'playcount']
# 🔄 Combinando datasets por track_id
#    → Data combinada tiene 9711301 filas y columnas ['track_id', 'user_id', 'playcount', 'name', 'artist', 'spotify_preview_url', 'spotify_id', 'tags', 'genre', 'year', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']
# 💾 Dataset combinado guardado en: ..\data\processed\million_song_combined.parquet
# ...

# %%
# Celda 3: Vista previa de datos
print(df.columns.tolist())
df.head(15)
# Out:
# ['track_id', 'user_id', 'playcount', 'name', 'artist', 'spotify_preview_url', 'spotify_id', 'tags', 'genre', 'year', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']
#               track_id                                   user_id  playcount  \
# 0   TRIRLYL128F42539D1  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 1   TRFUPBA128F934F7E1  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 2   TRLQPQJ128F42AA94F  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 3   TRTUCUY128F92E1D24  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 4   TRHDDQG12903CB53EE  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 5   TRGRDEC128F423C07D  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 6   TRRYCBO128F932A2C7  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 7   TRUTULC128F4293712  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# ...

# %%
# Celda 4: Estadísticas básicas
print("Estadísticas numéricas:")
display(df.describe())
# Out:
# Estadísticas numéricas:
#           playcount          year   duration_ms  danceability        energy  \
# count  9.711301e+06  9.711301e+06  9.711301e+06  9.711301e+06  9.711301e+06
# mean   2.630946e+00  2.004846e+03  2.458999e+05  5.286417e-01  6.781073e-01
# std    5.706324e+00  7.017311e+00  9.017579e+04  1.708274e-01  2.362942e-01
# min    1.000000e+00  1.900000e+03  1.439000e+03  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  2.002000e+03  1.979460e+05  4.130000e-01  5.230000e-01
# 50%    1.000000e+00  2.007000e+03  2.335730e+05  5.320000e-01  7.250000e-01
# 75%    2.000000e+00  2.009000e+03  2.750400e+05  6.480000e-01  8.810000e-01
# max    2.948000e+03  2.020000e+03  2.510920e+06  9.860000e-01  1.000000e+00
#
#                 key      loudness          mode   speechiness  acousticness  \
# count  9.711301e+06  9.711301e+06  9.711301e+06  9.711301e+06  9.711301e+06
# mean   5.351573e+00 -7.825038e+00  6.474253e-01  7.136620e-02  2.206536e-01
# ...

# %%
# Celda 5: Conteo de géneros (puede tener nulos)
print("Top 10 géneros más frecuentes:")
genre_counts = df['genre'].fillna('unknown').value_counts().head(10)
display(genre_counts)
# Out:
# Top 10 géneros más frecuentes:
# genre
# rock          3421185
#               3388151
# electronic     863233
# pop            519802
# rap            329210
# metal          327676
# country        219870
# folk           164813
# rnb            131583
# reggae          81630
# Name: count, dtype: int64

# %%
# Celda 6: Distribución playcount (uso)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.histplot(df['playcount'], bins=50, log_scale=True)
plt.title("Distribución de playcount (log escala)")
plt.xlabel("Playcount")
plt.ylabel("Cantidad de reproducciones")
plt.show()

# %%
# Celda 7: Top 10 artistas por número de escuchas
top_artists = df.groupby('artist')['playcount'].sum().sort_values(ascending=False).head(20)
print("Top 20 artistas por playcount:")
display(top_artists)
# Out:
# Top 20 artistas por playcount:
# artist
# kings of leon         597299
# the black keys        336178
# justin bieber         231001
# coldplay              203320
# radiohead             179341
# jack johnson          177147
# modest mouse          174356
# metallica             166320
# john mayer            160425
# metric                159881
# lady gaga             156092
# eminem                146204
# bon iver              139929
# beirut                139011
# the postal service    136836
# owl city              130872
# gorillaz              128506
# rise against          126889
# a day to remember     126040
# enya                  125692
# Name: playcount, dtype: int64
