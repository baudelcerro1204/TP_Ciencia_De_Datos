# %%
# TP_Ciencia_de_Datos/notebooks/MillionSongDataset_AED.ipynb

# Celda 1: Imports y setup
import sys
from pathlib import Path
sys.path.append(str(Path('../src/songrecommender').resolve()))

import pandas as pd
from processors.data_processing import MillionSongDataProcessor  # Asegúrate que la clase esté en este archivo

# %%
# Celda 2: Procesar datos
processor = MillionSongDataProcessor()
df = processor.process_all()

print(f"Dataset combinado con {len(df)} filas y {len(df.columns)} columnas")
# Out:
# 🔍 Cargando Music Info desde ..\data\raw\Music Info.csv
#    → 50683 filas, columnas: ['track_id', 'name', 'artist', 'spotify_preview_url', 'spotify_id', 'tags', 'genre', 'year', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']
# 🧹 Music Info limpio: 50683 filas
# 🔍 Cargando User Listening History desde ..\data\raw\User Listening History.csv
#    → 9711301 filas, columnas: ['track_id', 'user_id', 'playcount']
# 🔄 Combinando datasets por track_id
#    → Data combinada tiene 9711301 filas y columnas ['track_id', 'user_id', 'playcount', 'name', 'artist', 'spotify_preview_url', 'spotify_id', 'tags', 'genre', 'year', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']
# 🧹 Dataset reducido a features relevantes: ['track_id', 'name', 'artist', 'genre', 'duration_ms', 'danceability', 'energy', 'loudness', 'speechiness', 'valence', 'tempo']
# 💾 Dataset combinado guardado en: ..\data\processed\million_song_combined.parquet
# Dataset combinado con 9711301 filas y 11 columnas

# %%
# Celda 3: Vista previa de datos
print(df.columns.tolist())
df.head(15)
# Out:
# ['track_id', 'name', 'artist', 'genre', 'duration_ms', 'danceability', 'energy', 'loudness', 'speechiness', 'valence', 'tempo']
#               track_id                           name                artist  \
# 0   TRIRLYL128F42539D1           nothing from nothing         billy preston
# 1   TRFUPBA128F934F7E1                  paper gangsta             lady gaga
# 2   TRLQPQJ128F42AA94F                            soy           gipsy kings
# 3   TRTUCUY128F92E1D24                 stacked actors          foo fighters
# 4   TRHDDQG12903CB53EE  heaven's gonna burn your eyes  thievery corporation
# 5   TRGRDEC128F423C07D                 let it be sung          jack johnson
# 6   TRRYCBO128F932A2C7                     love shack            the b-52's
# 7   TRUTULC128F4293712                 gimme stitches          foo fighters
# 8   TRAAHSY128F147BB5C                 speed of sound              coldplay
# 9   TRDLMWP128F426BF6C                    ragged wood           fleet foxes
# 10  TRMSZXT128F92F7816           love song for no one            john mayer
# 11  TRVODUZ128F934D094           all that we perceive  thievery corporation
# 12  TRLXSNR128F429361D                      generator          foo fighters
# 13  TRPUGUW128F426BF6F            he doesn't know why           fleet foxes
# 14  TRAUCNU128F42671EB              tu quieres volver       sarah brightman
#
#          genre  duration_ms  danceability  energy  loudness  speechiness  \
# 0          rnb       155453         0.759   0.834    -5.206       0.0276
# 1          pop       260000         0.823   0.530    -9.344       0.0579
# 2                    187106         0.797   0.592   -11.647       0.0673
# 3         rock       256440         0.502   0.934    -5.145       0.0500
# 4   electronic       250360         0.516   0.337    -9.812       0.0286
# 5                    248346         0.565   0.469   -10.735       0.0303
# 6                    323586         0.662   0.902    -4.407       0.0532
# 7         rock       222200         0.538   0.958    -4.423       0.0680
# 8         rock       287906         0.523   0.898    -6.765       0.0567
# 9                    305320         0.355   0.685    -5.963       0.0299
# 10        rock       201560         0.528   0.755    -4.671       0.0311
# 11  electronic       226159         0.697   0.834    -6.470       0.0336
# 12        rock       227560         0.468   0.924    -3.937       0.0410
# 13        rock       199560         0.496   0.558    -5.535       0.0302
# 14                   229040         0.446   0.376    -9.766       0.0278
#
#     valence    tempo
# 0     0.939  102.792
# 1     0.800  100.002
# 2     0.851  104.518
# 3     0.670  134.898
# 4     0.323  152.411
# 5     0.487   62.508
# 6     0.882  133.672
# 7     0.541  111.842
# 8     0.355  123.085
# 9     0.169  103.695
# 10    0.432  144.024
# 11    0.959   90.478
# 12    0.593  152.694
# 13    0.436   93.989
# 14    0.192  140.416

# %%
# Celda 4: Estadísticas básicas
print("Estadísticas numéricas:")
display(df.describe())
# Out:
# Estadísticas numéricas:
#         duration_ms  danceability        energy      loudness   speechiness  \
# count  9.711301e+06  9.711301e+06  9.711301e+06  9.711301e+06  9.711301e+06
# mean   2.458999e+05  5.286417e-01  6.781073e-01 -7.825038e+00  7.136620e-02
# std    9.017579e+04  1.708274e-01  2.362942e-01  3.952011e+00  7.312056e-02
# min    1.439000e+03  0.000000e+00  0.000000e+00 -6.000000e+01  0.000000e+00
# 25%    1.979460e+05  4.130000e-01  5.230000e-01 -9.623000e+00  3.350000e-02
# 50%    2.335730e+05  5.320000e-01  7.250000e-01 -6.919000e+00  4.440000e-02
# 75%    2.750400e+05  6.480000e-01  8.810000e-01 -5.089000e+00  7.450000e-02
# max    2.510920e+06  9.860000e-01  1.000000e+00  3.642000e+00  9.540000e-01
#
#             valence         tempo
# count  9.711301e+06  9.711301e+06
# mean   4.658363e-01  1.234290e+02
# std    2.508728e-01  2.907696e+01
# min    0.000000e+00  0.000000e+00
# 25%    2.620000e-01  1.008950e+02
# 50%    4.420000e-01  1.218570e+02
# 75%    6.710000e-01  1.420110e+02
# max    9.890000e-01  2.388950e+02

# %%
# Celda 5: Conteo de géneros (puede tener nulos)
print("Top 10 géneros más frecuentes:")
genre_counts = df['genre'].fillna('unknown').value_counts().head(10)
display(genre_counts)
# Out:
# Top 10 géneros más frecuentes:
# genre
# rock          3421185
#               3388151
# electronic     863233
# pop            519802
# rap            329210
# metal          327676
# country        219870
# folk           164813
# rnb            131583
# reggae          81630
# Name: count, dtype: int64

# %%
# Celda 7: Top 10 artistas por número de escuchas
top_artists = df.groupby('artist').sum().sort_values(ascending=False).head(20)
print("Top 20 artistas por playcount:")
display(top_artists)
